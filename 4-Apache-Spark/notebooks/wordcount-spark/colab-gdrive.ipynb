# %%
#configuración de Spark en Google Colab
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#configuración de Spark en Google Colab
#instalar java y spark
# !apt-get install openjdk-17-jdk-headless -qq > /dev/null
# !wget -q https://downloads.apache.org/spark/spark-4.0.1/spark-4.0.1-bin-hadoop3.tgz
# !tar xf spark-4.0.1-bin-hadoop3.tgz
# !pip install -q findspark

# %%
#configuración de Spark en Google Colab
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-17-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-4.0.1-bin-hadoop3"

# %%
#configuración de Spark en Google Colab
import findspark
findspark.init()

# %%
#configuración de Spark en Google Colab
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()
sc = spark.sparkContext

# %%
# en gdrive:
files_rdd = sc.textFile("gdrive/MyDrive/datasets/gutenberg-small/*.txt")

wc_unsort = files_rdd.flatMap(lambda line: line.split()).map(lambda word: (word, 1)).reduceByKey(lambda a, b: a + b)
wc = wc_unsort.sortBy(lambda a: -a[1])
for tupla in wc.take(10):
        print(tupla)
# Out:
# ('the', 44647)
# ('of', 28020)
# ('to', 23208)
# ('and', 20444)
# ('in', 13174)
# ('that', 12265)
# ('I', 10880)
# ('a', 10431)
# ('is', 7776)
# ('be', 7148)

# %% [markdown]
# # WORDCOUNT PASO A PASO

# %%
files = sc.textFile("gdrive/MyDrive/datasets/gutenberg-small/*.txt")
for f in files.take(10):
    print(f)
# Out:
# LINCOLN LETTERS
#
# By Abraham Lincoln
#
#
# Published by The Bibilophile Society

# %%
tokens = files.flatMap(lambda line: line.split())
for t in tokens.take(10):
    print(t)
# Out:
# LINCOLN
# LETTERS
# By
# Abraham
# Lincoln
# Published
# by
# The
# Bibilophile
# Society

# %%
wc1 = tokens.map(lambda word: (word, 1))
for c in wc1.take(10):
    print(c)
# Out:
# ('LINCOLN', 1)
# ('LETTERS', 1)
# ('By', 1)
# ('Abraham', 1)
# ('Lincoln', 1)
# ('Published', 1)
# ('by', 1)
# ('The', 1)
# ('Bibilophile', 1)
# ('Society', 1)

# %%
wc = wc1.reduceByKey(lambda a, b: a + b)
for c in wc.take(10):
    print(c)
# Out:
# ('Published', 3)
# ('themselves', 192)
# ('were', 1450)
# ('sheet', 4)
# ('despatched', 4)
# ('most', 551)
# ('turbulent', 2)
# ('A.', 1456)
# ('ORIGINALS', 1)
# ('IN', 84)

# %%
wcsort = wc.sortBy(lambda a: -a[1])
for c in wcsort.take(10):
    print(c)
# Out:
# ('the', 44647)
# ('of', 28020)
# ('to', 23208)
# ('and', 20444)
# ('in', 13174)
# ('that', 12265)
# ('I', 10880)
# ('a', 10431)
# ('is', 7776)
# ('be', 7148)
