# %%
spark
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>1</td><td>application_1763396678263_0002</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-172-31-70-192.ec2.internal:20888/proxy/application_1763396678263_0002/">Link</a></td><td><a target="_blank" href="http://ip-172-31-76-109.ec2.internal:8042/node/containerlogs/container_1763396678263_0002_01_000001/livy">Link</a></td><td>None</td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# <pyspark.sql.session.SparkSession object at 0x7effa54e1d30>

# %%
sc
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# <SparkContext master=yarn appName=livy-session-1>

# %% [markdown]
# ## Word Count Compacto

# %%
bucket = "lmtorresv-datalake"
files_rdd = sc.textFile(f"s3a://{bucket}/datasets/gutenberg-small/*.txt")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
wc_unsort = files_rdd.flatMap(lambda line: line.split()).map(lambda word: (word, 1)).reduceByKey(lambda a, b: a + b)
wc = wc_unsort.sortBy(lambda a: -a[1])
for tupla in wc.take(10):
        print(tupla)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ('the', 44647)
# ('of', 28020)
# ('to', 23208)
# ('and', 20444)
# ('in', 13174)
# ('that', 12265)
# ('I', 10880)
# ('a', 10431)
# ('is', 7776)
# ('be', 7148)

# %% [markdown]
# ## Word Count: paso a paso

# %%
bucket = "lmtorresv-datalake"
files = sc.textFile(f"s3a://{bucket}/datasets/gutenberg-small/*.txt")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
for f in files.take(10):
    print(f)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# LINCOLN LETTERS
#
# By Abraham Lincoln
#
#
# Published by The Bibilophile Society

# %%
tokens = files.flatMap(lambda line: line.split())
for t in tokens.take(10):
    print(t)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# LINCOLN
# LETTERS
# By
# Abraham
# Lincoln
# Published
# by
# The
# Bibilophile
# Society

# %%
wc1 = tokens.map(lambda word: (word, 1))
for c in wc1.take(10):
    print(c)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ('LINCOLN', 1)
# ('LETTERS', 1)
# ('By', 1)
# ('Abraham', 1)
# ('Lincoln', 1)
# ('Published', 1)
# ('by', 1)
# ('The', 1)
# ('Bibilophile', 1)
# ('Society', 1)

# %%
wc = wc1.reduceByKey(lambda a, b: a + b)
for c in wc.take(10):
    print(c)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ('thoroughly', 15)
# ('themselves', 192)
# ('them.', 371)
# ('letter', 312)
# ('A.', 1456)
# ('ORIGINALS', 1)
# ('THEY', 1)
# ('sum', 59)
# ('singular', 18)
# ('let', 414)

# %%
wcsort = wc.sortBy(lambda a: -a[1])
for c in wcsort.take(10):
    print(c)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ('the', 44647)
# ('of', 28020)
# ('to', 23208)
# ('and', 20444)
# ('in', 13174)
# ('that', 12265)
# ('I', 10880)
# ('a', 10431)
# ('is', 7776)
# ('be', 7148)
